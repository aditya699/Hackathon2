# %% [markdown]
# # Explainable AI

# %%
# Import necessary models
from pycaret.regression import *
import pandas as pd
import numpy as np

# %%
data_train=pd.read_csv('Data/Train/model_train.csv')
data_test=pd.read_csv('Data/Train/model_test.csv')

# %%
s = setup(data_train, target = 'SalePrice', session_id = 123)
# Out:
# <style type="text/css">
# #T_0b3c3_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_0b3c3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0b3c3_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_0b3c3_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0b3c3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0b3c3_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_0b3c3_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_0b3c3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0b3c3_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_0b3c3_row1_col1" class="data row1 col1" >SalePrice</td>
#     </tr>
#     <tr>
#       <th id="T_0b3c3_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models(include=['gbr','et','rf'])
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           07:49:30
# Status     . . . . . . . . . . . . . . . . . .  Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Compiling Library
# <style type="text/css">
# #T_87cbd th {
#   text-align: left;
# }
# #T_87cbd_row0_col0, #T_87cbd_row1_col0, #T_87cbd_row1_col1, #T_87cbd_row1_col2, #T_87cbd_row1_col3, #T_87cbd_row1_col4, #T_87cbd_row1_col5, #T_87cbd_row1_col6, #T_87cbd_row2_col0, #T_87cbd_row2_col1, #T_87cbd_row2_col2, #T_87cbd_row2_col3, #T_87cbd_row2_col4, #T_87cbd_row2_col5, #T_87cbd_row2_col6 {
#   text-align: left;
# }
# #T_87cbd_row0_col1, #T_87cbd_row0_col2, #T_87cbd_row0_col3, #T_87cbd_row0_col4, #T_87cbd_row0_col5, #T_87cbd_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_87cbd_row0_col7, #T_87cbd_row1_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_87cbd_row2_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# ...

# %% [markdown]
# # Plot the Model

# %%
plot_model(best, plot = 'residuals')

# %% [markdown]
# # Plot the error

# %%
# plot error
plot_model(best, plot = 'error')

# %% [markdown]
# # Feature Importance Plot

# %%
# plot feature importance
plot_model(best, plot = 'feature')

# %% [markdown]
# # Visualizing the pipeline created

# %%
# save pipeline
save_model(best, 'my_model_pipeline')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=C:\Users\aditya\AppData\Local\Temp\joblib),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['MSSubClass', 'Utilities',
#                                               'LandSlope', 'MasVnrArea',
#                                               'ExterQual', 'ExterCond',
#                                               'TotalBsmtSF', 'CentralAir',
#                                               '1stFlrSF', '2ndFlrSF',
#                                               'LowQualFinSF', 'GrLivArea',
#                                               'BsmtFullBath', 'BsmtHalfBath',
#                                               'FullBath', 'HalfBath',
#                                               'BedroomAbvGr...
#                                               'PavedDrive', 'SaleType',
#                                               'SaleCondition'],
# ...

# %%
# load pipeline
loaded_best_pipeline = load_model('my_model_pipeline')
loaded_best_pipeline
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(memory=FastMemory(location=C:\Users\aditya\AppData\Local\Temp\joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=['MSSubClass', 'Utilities',
#                                              'LandSlope', 'MasVnrArea',
#                                              'ExterQual', 'ExterCond',
#                                              'TotalBsmtSF', 'CentralAir',
#                                              '1stFlrSF', '2ndFlrSF',
#                                              'LowQualFinSF', 'GrLivArea',
#                                              'BsmtFullBath', 'BsmtHalfBath',
#                                              'FullBath', 'HalfBath',
#                                              'BedroomAbvGr...
#                                              'PavedDrive', 'SaleType',
#                                              'SaleCondition'],
# ...

# %% [markdown]
# # Interpret model

# %%
create_app(best)
# Out:
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
